# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeFonse/matematicasdiscre/blob/main/BaseEnBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ACTIVIDAD: DE BASE EN BASE**
#
#
# Conformar equipos de trabajo con 4 integrantes para desarrollar las actividades propuestas.
#
# ### 1. Realizar las conversiones indicadas
# A. 380 <sub>10</sub> a binario
#
# B. 940<sub>7</sub> a octal
#
# C. 102<sub>5</sub> a decimal
#
# D. 1011011<sub>2</sub> a nonario

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ### 2. Los siguientes números están en BCD. Convertirlos a decimal.
# A. 00011110100101010010
#
# B. 000110000100
#
# C. 0111011101110101
#
# D. 010010010010

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ###3. Realizar las sumas indicadas de números binarios
# A. 100111<sub>2</sub> + 110111<sub>2</sub> + 100111<sub>2</sub>
#
# B. 110010<sub>2</sub>+ 100001<sub>2</sub> + 1111<sub>2</sub>
#
# C. 1101010<sub>2</sub> + 1010111<sub>2</sub>
#
# D. 1100.0111<sub>2</sub> + 111.01<sub>2</sub>

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ### 4. Convertir los siguientes números decimales a sus valores binarios.
# A. 5534<sub>10</sub>
#
# B. 20,5<sub>10</sub>
#
# C. 643,2<sub>10</sub>
#
# D. 260,5<sub>10</sub>

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ### 5. Represente el número decimal 80 en cada una de las siguientes formas:
# A. Binario puro
#
# B. BCD
#
# C. Octal
#
# D. Hexadecimal

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ### 6. Convertir los siguientes números binarios a sus valores decimales
# A. 1101,1011<sub>2</sub>
#
# B. 11010011101,11101<sub>2</sub>

# %% [markdown]
# Inserte la imagen de evidencia del cuaderno en este apartado,
# dando doble click

# %% [markdown]
# ### 7. Cuál es el valor decimal mayor que se puede representar con un número binario de:
# A. 8 bits
#
# B. 16 bits
#
# C. 12 bits

# %% [markdown]
# ![EJERCICIOS 7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 8. Convertir los siguientes números hexadecimales a binarios:
# A. 96<sub>Hex</sub>
#
# B. 35B<sub>Hex</sub>
#
# C. AFF<sub>Hex</sub>

# %% [markdown]
# ## Extraido de documento R1-A2-S3 Elaborado por: Bernabé Buitrago Domínguez.
# ## Docente Ciencias Básicas

# %% [markdown]
# ![EJERCICIOS 8.png](data:image/png;base64,...)
